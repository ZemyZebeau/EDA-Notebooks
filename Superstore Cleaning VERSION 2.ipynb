# %% [markdown]
# # Superstore Cleaning VERSION 2
#
# Zachary Lewis

# %% [markdown]
# # Missing Values - VER. 2

# %% [markdown]
# The Superstore operates internationally but only logs postal codes for customers in the US hence the large number of null fields. Furthermore, the column's data type is float resulting in postal codes with decimal points.

# %% [markdown]
# In the last assignment, I thought changing the `Postal Code` column from `float` to `int` was correct. I was mistaken and had missed that some states, e.g. Massachusettes, Connecticut, and New Jersey, saw postal codes beginning with zero altered due to Pandas automatically assigning the column's data type to `float`.
#
# I addressed this with guidance from the videos embedded on the assignment page.

# %%
# Import in Pandas library as 'pd'
import pandas as pd

# Fully show all columns in dataframes
pd.set_option('display.max.columns', None)

# Automatically connect with Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Pull dataset from Google Drive and assigns it to path
path = '/content/drive/MyDrive/Newman/Descriptive Analytics/Superstore EDA/data/Global_Superstore_Orders_2012_2015.xlsx'

# Read data into df and specify an object data type for Postal Code
df = pd.read_excel(path, dtype={'Postal Code': object})

# Adjust values with missing characters and replaces '00nan' with 'na'
df['Postal Code'] = df['Postal Code'].astype('str').str.zfill(5).replace('00nan', 'na')

# Assign 'Sales', 'Discount', 'Profit', 'Shipping Cost' to 'columns'
columns = ['Sales', 'Discount', 'Profit', 'Shipping Cost']

# Round the values of the group of columns assigned to 'columns' by two decimals
df[columns] = df[columns].round(2)

# Return a sample of twenty rows from dataset
df.sample(20)
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 49955    6648   MX-2015-RB1957031-42349 2015-12-11 2015-12-15  Standard Class
# 31789   24812    IN-2014-MV181907-41966 2014-11-23 2014-11-26    Second Class
# 26917   12554   ES-2014-KW1657048-41865 2014-08-14 2014-08-18  Standard Class
# 14029   19068   ES-2013-GH1441064-41489 2013-08-03 2013-08-05    Second Class
# 3867     7540   MX-2012-GD1459082-41118 2012-07-28 2012-07-30    Second Class
# 13445   35572  CA-2013-KN16450140-41464 2013-07-09 2013-07-13  Standard Class
# 44604   49873     IR-2015-AR51060-42265 2015-09-18 2015-09-23  Standard Class
# 3235    48156   SA-2012-JH5820110-41083 2012-06-23 2012-06-28  Standard Class
# 9405    27395  IN-2013-AT10735144-41296 2013-01-22 2013-01-22        Same Day
# 7084    36849  US-2012-DB12970140-41224 2012-11-11 2012-11-15  Standard Class
# 49665   18170   ES-2015-AS1004545-42346 2015-12-08 2015-12-14  Standard Class
# 18720   14676   IT-2013-SS2014045-41611 2013-12-03 2013-12-07  Standard Class
# 25269   50437    MO-2014-MH745586-41817 2014-06-27 2014-07-02  Standard Class
# 21082   23940    ID-2014-FP143207-41690 2014-02-20 2014-02-25  Standard Class
# 32032   15923  ES-2014-RB19570120-41971 2014-11-28 2014-12-04  Standard Class
# 7211    19936  IT-2012-RP19270124-41228 2012-11-15 2012-11-22  Standard Class
# 19239    5851   MX-2013-AA1064518-41622 2013-12-14 2013-12-16    Second Class
# 47416   12389   ES-2015-TB2125048-42315 2015-11-07 2015-11-12    Second Class
# 40157   19264   ES-2015-JK1532545-42179 2015-06-24 2015-06-26    Second Class
# 41290   48496    MO-2015-LC693086-42206 2015-07-21 2015-07-25  Standard Class
#
#         Customer ID      Customer Name      Segment Postal Code  \
# 49955    RB-1957031        Rob Beeghly     Consumer          na
# 31789     MV-181907     Mike Vittorini     Consumer          na
# 26917    KW-1657048     Kelly Williams     Consumer          na
# 14029    GH-1441064        Gary Hansen  Home Office          na
# 3867     GD-1459082   Giulietta Dortch    Corporate          na
# 13445  KN-164501402        Kean Nguyen    Corporate       75220
# 44604      AR-51060     Andrew Roberts     Consumer          na
# 3235     JH-5820110        John Huston     Consumer          na
# 9405    AT-10735144      Annie Thurman     Consumer          na
# 7084   DB-129701402        Darren Budd    Corporate       77036
# 49665    AS-1004545     Aaron Smayling    Corporate          na
# 18720    SS-2014045   Saphhira Shifley    Corporate          na
# 25269     MH-745586      Mark Hamilton     Consumer          na
# 21082     FP-143207        Frank Preis     Consumer          na
# 32032   RB-19570120        Rob Beeghly     Consumer          na
# 7211    RP-19270124       Rachel Payne    Corporate          na
# 19239    AA-1064518      Anna Andreadi     Consumer          na
# 47416    TB-2125048       Tim Brockman     Consumer          na
# 40157    JK-1532545  Jason Klamczynski    Corporate          na
# 41290     LC-693086     Linda Cazamias    Corporate          na
#
#                    City                               State        Country  \
# 49955  Santiago de Cuba                    Santiago de Cuba           Cuba
# 31789        Townsville                          Queensland      Australia
# 26917       Brandenburg                         Brandenburg        Germany
# 14029            Venice                              Veneto          Italy
# 3867     Miguel Hidalgo                    Distrito Federal         Mexico
# 13445            Dallas                               Texas  United States
# 44604              Yazd                                Yazd           Iran
# 3235             Jeddah                              Makkah   Saudi Arabia
# 9405            Can Tho                        Tỉnh Cần Thơ        Vietnam
# 7084            Houston                               Texas  United States
# 49665         Le Cannet          Provence-Alpes-Côte d'Azur         France
# 18720          Toulouse  Languedoc-Roussillon-Midi-Pyrénées         France
# 25269         Khouribga                   Chaouia-Ouardigha        Morocco
# 21082         Newcastle                     New South Wales      Australia
# 32032         Barakaldo                      Basque Country          Spain
# 7211          Stockholm                           Stockholm         Sweden
# 19239           Aracati                               Ceará         Brazil
# 47416               Ulm                   Baden-Württemberg        Germany
# 40157             Torcy                       Ile-de-France         France
# 41290        Casablanca                    Grand Casablanca        Morocco
#
#                   Region        Market   Product ID         Category  \
# 49955          Caribbean         LATAM  OFF-BI-2881  Office Supplies
# 31789            Oceania  Asia Pacific  OFF-AR-6124  Office Supplies
# 26917     Western Europe        Europe  OFF-ST-4293  Office Supplies
# 14029    Southern Europe        Europe  OFF-LA-4662  Office Supplies
# 3867     Central America         LATAM  OFF-ST-6023  Office Supplies
# 13445         Central US          USCA  OFF-AP-2889  Office Supplies
# 44604      Southern Asia  Asia Pacific  OFF-BI-3291  Office Supplies
# 3235        Western Asia  Asia Pacific  FUR-FU-6278        Furniture
# 9405   Southeastern Asia  Asia Pacific  TEC-CO-4779       Technology
# 7084          Central US          USCA  TEC-AC-4871       Technology
# 49665     Western Europe        Europe  OFF-AP-4955  Office Supplies
# 18720     Western Europe        Europe  FUR-BO-3892        Furniture
# 25269       North Africa        Africa  OFF-AR-5933  Office Supplies
# 21082            Oceania  Asia Pacific  TEC-PH-5836       Technology
# 32032    Southern Europe        Europe  OFF-AP-4496  Office Supplies
# 7211     Northern Europe        Europe  OFF-BI-4824  Office Supplies
# 19239      South America         LATAM  OFF-AR-3456  Office Supplies
# 47416     Western Europe        Europe  OFF-AR-6115  Office Supplies
# 40157     Western Europe        Europe  OFF-AR-6127  Office Supplies
# 41290       North Africa        Africa  OFF-BI-2881  Office Supplies
#
#       Sub-Category                                       Product Name   Sales  \
# 49955      Binders                           Acco 3-Hole Punch, Clear   19.72
# 31789          Art                          Stanley Pens, Water Color   35.72
# 26917      Storage                               Fellowes Trays, Blue  154.95
# 14029       Labels           Hon Legal Exhibit Labels, 5000 Label Set   67.50
# 3867       Storage                                    Smead Box, Blue   43.08
# 13445   Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...   48.63
# 44604      Binders                 Avery Hole Reinforcements, Economy    8.82
# 3235   Furnishings                     Tenex Stacking Tray, Erganomic   23.85
# 9405       Copiers                                 HP Ink, High-Speed  159.89
# 7084   Accessories  Imation 16GB Mini TravelDrive USB 2.0 Flash Drive   79.51
# 49665   Appliances                   KitchenAid Coffee Grinder, White  555.74
# 18720    Bookcases                Dania Classic Bookcase, Traditional  985.82
# 25269          Art                    Sanford Sketch Pad, Water Color   48.66
# 21082       Phones                  Samsung Signal Booster, Full Size  124.09
# 32032   Appliances               Hamilton Beach Coffee Grinder, White   81.60
# 7211       Binders                 Ibico Hole Reinforcements, Durable    4.24
# 19239          Art                                  BIC Markers, Blue   35.24
# 47416          Art                        Stanley Markers, Easy-Erase   67.41
# 40157          Art                    Stanley Sketch Pad, Fluorescent  182.76
# 41290      Binders                           Acco 3-Hole Punch, Clear   59.16
#
#        Quantity  Discount  Profit  Shipping Cost Order Priority
# 49955         1      0.00    3.34           2.89           High
# 31789         3      0.10    1.52           4.38           High
# 26917         3      0.10   -5.25           7.92           High
# 14029         6      0.00   12.06           9.34           High
# 3867          6      0.00   17.16          10.88       Critical
# 13445         2      0.80 -121.58           1.27         Medium
# 44604         2      0.00    0.00           1.43         Medium
# 3235          1      0.00    1.65           2.17         Medium
# 9405          2      0.37   15.17          18.26           High
# 7084          3      0.20   20.87           4.98         Medium
# 49665         9      0.10  154.25           5.95         Medium
# 18720         6      0.60 -419.08         112.85           High
# 25269         1      0.00   22.86           3.81         Medium
# 21082         1      0.10  -11.06           9.42         Medium
# 32032         2      0.00   35.88          14.24            Low
# 7211          1      0.50   -1.88           1.64            Low
# 19239         2      0.00   13.72           5.24           High
# 47416         3      0.00    0.00           7.28           High
# 40157         4      0.00   29.16          64.33       Critical
# 41290         2      0.00   10.02           5.10         Medium

# %%
# Check for improper values.
df[df['State'].str.contains('Mass')]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 1363    39250  CA-2012-KH16330140-40999 2012-03-31 2012-04-05  Standard Class
# 1364    39251  CA-2012-KH16330140-40999 2012-03-31 2012-04-05  Standard Class
# 2050    37862  CA-2012-CT11995140-41035 2012-05-06 2012-05-11  Standard Class
# 2051    37860  CA-2012-CT11995140-41035 2012-05-06 2012-05-11  Standard Class
# 2052    37859  CA-2012-CT11995140-41035 2012-05-06 2012-05-11  Standard Class
# ...       ...                       ...        ...        ...             ...
# 50140   38996  CA-2015-BF11170140-42353 2015-12-15 2015-12-19  Standard Class
# 50141   38997  CA-2015-BF11170140-42353 2015-12-15 2015-12-19  Standard Class
# 50840   40243  CA-2015-NC18535140-42363 2015-12-25 2015-12-29  Standard Class
# 50841   40244  CA-2015-NC18535140-42363 2015-12-25 2015-12-29  Standard Class
# 51285   47594    MO-2015-LP709586-42369 2015-12-31 2016-01-05  Standard Class
#
#         Customer ID    Customer Name      Segment Postal Code         City  \
# 1363   KH-163301406  Katharine Harms    Corporate       02151       Revere
# 1364   KH-163301406  Katharine Harms    Corporate       02151       Revere
# 2050   CT-119951406     Carol Triggs     Consumer       01841     Lawrence
# 2051   CT-119951406     Carol Triggs     Consumer       01841     Lawrence
# 2052   CT-119951406     Carol Triggs     Consumer       01841     Lawrence
# ...             ...              ...          ...         ...          ...
# 50140  BF-111701406       Ben Ferrer  Home Office       01841     Lawrence
# 50141  BF-111701406       Ben Ferrer  Home Office       01841     Lawrence
# 50840  NC-185351406    Nick Crebassa    Corporate       02740  New Bedford
# 50841  NC-185351406    Nick Crebassa    Corporate       02740  New Bedford
# 51285     LP-709586        Liz Preis     Consumer          na       Agadir
#
#                   State        Country        Region  Market   Product ID  \
# 1363      Massachusetts  United States    Eastern US    USCA  OFF-ST-5704
# 1364      Massachusetts  United States    Eastern US    USCA  OFF-BI-6634
# 2050      Massachusetts  United States    Eastern US    USCA  FUR-CH-5090
# 2051      Massachusetts  United States    Eastern US    USCA  FUR-TA-3333
# 2052      Massachusetts  United States    Eastern US    USCA  OFF-BI-2927
# ...                 ...            ...           ...     ...          ...
# 50140     Massachusetts  United States    Eastern US    USCA  OFF-SU-2981
# 50141     Massachusetts  United States    Eastern US    USCA  OFF-FA-2890
# 50840     Massachusetts  United States    Eastern US    USCA  OFF-PA-6577
# 50841     Massachusetts  United States    Eastern US    USCA  OFF-BI-3326
# 51285  Souss-Massa-Draâ        Morocco  North Africa  Africa  OFF-BI-6397
#
#               Category Sub-Category  \
# 1363   Office Supplies      Storage
# 1364   Office Supplies      Binders
# 2050         Furniture       Chairs
# 2051         Furniture       Tables
# 2052   Office Supplies      Binders
# ...                ...          ...
# 50140  Office Supplies     Supplies
# 50141  Office Supplies    Fasteners
# 50840  Office Supplies        Paper
# 50841  Office Supplies      Binders
# 51285  Office Supplies      Binders
#
#                                             Product Name   Sales  Quantity  \
# 1363           Rogers Profile Extra Capacity Storage Tub   66.96         4
# 1364                          Zipper Ring Binder Pockets    6.24         2
# 2050         Lifetime Advantage Folding Chairs, 4/Carton  872.32         4
# 2051            Balt Split Level Computer Training Table  194.25         2
# 2052   Acco PRESSTEX Data Binder with Storage Hooks, ...   16.14         3
# ...                                                  ...     ...       ...
# 50140  Acme Office Executive Series Stainless Steel T...   25.71         3
# 50141                  Acco Banker's Clasps, 5 3/4"-Long   17.28         6
# 50840                                          Xerox 214   19.44         3
# 50841  Avery Triangle Shaped Sheet Lifters, Black, 2/...   12.30         5
# 51285            Wilson Jones Hole Reinforcements, Clear    3.99         1
#
#        Discount  Profit  Shipping Cost Order Priority
# 1363        0.0    2.68           1.57         Medium
# 1364        0.0    3.06           1.34         Medium
# 2050        0.0  244.25          74.39           High
# 2051        0.3  -38.85          21.73           High
# 2052        0.0    7.91           2.87           High
# ...         ...     ...            ...            ...
# 50140       0.0    6.68           2.98           High
# 50141       0.0    8.12           2.05           High
# 50840       0.0    9.33           3.75           High
# 50841       0.0    6.15           1.94           High
# 51285       0.0    0.42           1.49         Medium
#
# [150 rows x 24 columns]

# %%
# Total count of rows and columns
# df.shape

# %%
# Information of column datatypes with number of nonnull values per column
# df.info()

# %%
# Sum of null values in the dataframe
# df.isna().sum()

# %%
# columns = ['Country', 'City', 'State', 'Postal Code']
# mask = df['Postal Code'].isnull()

# # df[columns].loc[mask].sort_index().head(20)

# %%
# columns = ['Country', 'City', 'State', 'Postal Code']
# mask = df['Postal Code'].notnull()

# df[columns].loc[mask].sort_values('Postal Code').head(20)

# %%
# df[columns].loc[mask].value_counts()

# %%
# df1[columns].loc[mask].value_counts().to_frame().sort_values('Postal Code').head(20)
# df[columns].loc[mask].value_counts().to_frame().sort_values('Postal Code').tail(20)

# %%
# df1 = pd.read_excel('/content/drive/MyDrive/Newman/Descriptive Analytics/Superstore EDA/data/Global_Superstore_Orders_2012_2015.xlsx', sheet_name = 0, dtype = {'Postal Code': 'object'})

# %%
# df1.sample(20)

# %% [markdown]
# # Reformat `Postal Code`

# %% [markdown]
# * Set as text data type: **object, string**
# * Ensure leading zeros are kept: for instance **01040**
# * Ensure nulls are recognizable as not applicable (for non-US addresses): **na**

# %%
# path = '/content/drive/MyDrive/Newman/Descriptive Analytics/Superstore EDA/data/Global_Superstore_Orders_2012_2015.xlsx'

# %%
# df1 = pd.read_excel(path, dtype={'Postal Code': object})

# %%
# df1.sample(20)

# %%
# df1['Postal Code'] = df1['Postal Code'].astype(str)
# df1['Postal Code'].sort_values()

# %%
# df1.info()

# %%
# df1['Postal Code'] = df1['Postal Code'].astype('str').str.zfill(5)
# column = ['Country', 'State', 'City', 'Postal Code']
# mask = df1['State'].str.contains('Conn') | df1['State'].str.contains('Mass')
# df1[columns].loc[mask].sort_values('Postal Code').head(20)

# %%
# df1['Postal Code'].unique()

# %%
# df1['Postal Code'] = df1['Postal Code'].replace('00nan', 'na')

# %%
# df1['Postal Code'].sort_values().unique()

# %%
# df1['Postal Code'].sample(10)
