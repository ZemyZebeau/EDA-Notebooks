# %% [markdown]
# # Olympics EDA: Read And Review
#
# Zachary Lewis

# %%
import pandas as pd
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.4)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly) (1.26.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 55.9 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed plotly-6.0.0

# %%
df_athletes = pd.read_csv('/content/drive/MyDrive/Newman/Descriptive Analytics/Olympics EDA /data/athlete_events.csv', sep =',', header = 'infer')
df_regions = pd.read_csv ('/content/drive/MyDrive/Newman/Descriptive Analytics/Olympics EDA /data/noc_regions.csv', sep = ',', header = 'infer')

# %%
df_athletes.head(10) # returns "10" rows starting from the top of the dataset
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating Women's 1,000 metres   NaN
# 8    Speed Skating Women's 500 metres   NaN
# 9  Speed Skating Women's 1,000 metres   NaN

# %%
df_regions.head(10)
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN
# 5  ANG       Angola                   NaN
# 6  ANT      Antigua   Antigua and Barbuda
# 7  ANZ    Australia           Australasia
# 8  ARG    Argentina                   NaN
# 9  ARM      Armenia                   NaN

# %%
df_athletes.tail(10) # returns "10" rows starting from the bottom of the dataset
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271113  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 271106      Argentina  ARG  2004 Summer  2004  Summer          Athina
# 271107  United States  USA  1972 Summer  1972  Summer          Munich
# 271108         Russia  RUS  2000 Summer  2000  Summer          Sydney
# 271109         Russia  RUS  2004 Summer  2004  Summer          Athina
# 271110        Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
# 271111       Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112         Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113         Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114         Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115         Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#               Sport                                     Event Medal
# 271106       Hockey                       Hockey Men's Hockey   NaN
# 271107     Football                   Football Men's Football   NaN
# 271108       Rowing    Rowing Men's Lightweight Coxless Fours   NaN
# 271109       Rowing    Rowing Men's Lightweight Coxless Fours   NaN
# 271110   Basketball             Basketball Women's Basketball   NaN
# 271111         Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113  Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114    Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115    Bobsleigh                      Bobsleigh Men's Four   NaN

# %%
df_regions.tail(10)
# Out:
#      NOC         region                   notes
# 220  VIE        Vietnam                     NaN
# 221  VIN  Saint Vincent                     NaN
# 222  VNM        Vietnam                     NaN
# 223  WIF       Trinidad  West Indies Federation
# 224  YAR          Yemen             North Yemen
# 225  YEM          Yemen                     NaN
# 226  YMD          Yemen             South Yemen
# 227  YUG         Serbia              Yugoslavia
# 228  ZAM         Zambia                     NaN
# 229  ZIM       Zimbabwe                     NaN

# %%
df_athletes.sample(10) #returns "10" random rows
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 31935    16409                  Edo Buma   M  22.0   183.0    80.0
# 199680  100299           Anjelika Reznik   F  17.0   166.0    45.0
# 21151    11168        Mislav Bezmalinovi   M  21.0   197.0    88.0
# 25421    13286     Klaus-Michael Bonsack   M  22.0   183.0    84.0
# 223879  112460        Albert "Art" Smoke   M   NaN   148.0     NaN
# 127349   64200                Hans Kroes   M  19.0   190.0    83.0
# 192816   96805  Erik Oluf Preben-Schmidt   M  29.0   175.0    82.0
# 210599  105743             Anna Sarayeva   F  21.0   165.0    63.0
# 131670   66264              Robyn Lamsam   F  14.0     NaN     NaN
# 225934  113534           Aye Oktay Szeri   F  22.0   178.0    70.0
#
#                Team  NOC        Games  Year  Season         City  \
# 31935   Netherlands  NED  1968 Summer  1968  Summer  Mexico City
# 199680       Canada  CAN  2012 Summer  2012  Summer       London
# 21151    Yugoslavia  YUG  1988 Summer  1988  Summer        Seoul
# 25421     Germany-2  GER  1964 Winter  1964  Winter    Innsbruck
# 223879       Canada  CAN  1920 Summer  1920  Summer    Antwerpen
# 127349  Netherlands  NED  1984 Summer  1984  Summer  Los Angeles
# 192816       Brazil  BRA  1968 Summer  1968  Summer  Mexico City
# 210599       Russia  RUS  2000 Summer  2000  Summer       Sydney
# 131670    Hong Kong  HKG  1992 Summer  1992  Summer    Barcelona
# 225934       Turkey  TUR  1996 Summer  1996  Summer      Atlanta
#
#                       Sport                                  Event Medal
# 31935                Hockey                    Hockey Men's Hockey   NaN
# 199680  Rhythmic Gymnastics      Rhythmic Gymnastics Women's Group   NaN
# 21151            Water Polo            Water Polo Men's Water Polo  Gold
# 25421                  Luge             Luge Mixed (Men)'s Doubles   NaN
# 223879            Athletics               Athletics Men's Marathon   NaN
# 127349             Swimming   Swimming Men's 100 metres Backstroke   NaN
# 192816              Sailing      Sailing Mixed Two Person Keelboat   NaN
# 210599                 Judo         Judo Women's Half-Middleweight   NaN
# 131670             Swimming  Swimming Women's 400 metres Freestyle   NaN
# 225934              Sailing             Sailing Women's Windsurfer   NaN

# %%
df_regions.sample(10)
# Out:
#      NOC       region notes
# 60   EGY        Egypt   NaN
# 171  RUS       Russia   NaN
# 187  SSD  South Sudan   NaN
# 73   GAM       Gambia   NaN
# 81   GRE       Greece   NaN
# 62   ESA  El Salvador   NaN
# 110  KOS       Kosovo   NaN
# 185  SRB       Serbia   NaN
# 114  LAT       Latvia   NaN
# 174  SAM        Samoa   NaN

# %%
df_athletes.shape #returns total number of rows and columns within a dataset
# Out:
# (271116, 15)

# %%
df_regions.shape
# Out:
# (230, 3)

# %%
df_athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df_regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
df_athletes.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df_regions.describe()
# Out:
#         NOC   region                 notes
# count   230      227                    21
# unique  230      206                    21
# top     AFG  Germany  Netherlands Antilles
# freq      1        4                     1

# %%
df_athletes.describe(include = 'object')
# Out:
#                         Name     Sex           Team     NOC        Games  \
# count                 271116  271116         271116  271116       271116
# unique                134732       2           1184     230           51
# top     Robert Tait McKenzie       M  United States     USA  2000 Summer
# freq                      58  196594          17847   18853        13821
#
#         Season    City      Sport                    Event  Medal
# count   271116  271116     271116                   271116  39783
# unique       2      42         66                      765      3
# top     Summer  London  Athletics  Football Men's Football   Gold
# freq    222552   22426      38624                     5733  13372

# %% [markdown]
# ##Sample Tests

# %%
#query for athletes under the age of 18 sorted by year(s) they competed in and age.
young_athletes = df_athletes[(df_athletes['Age'] < 18 )].sort_values(by = ['Year', 'Age'])

# %%
young_athletes.head(10)
# Out:
#            ID                                               Name Sex   Age  \
# 142882  71691                                 Dimitrios Loundras   M  10.0
# 51139   26280                         Georges Daviel de la Nzire   M  17.0
# 182918  91932                      Khios "Konstantinos" Paspatis   M  17.0
# 182919  91932                      Khios "Konstantinos" Paspatis   M  17.0
# 187185  94075                    Dimitrios Stephen Petrokokkinos   M  17.0
# 187186  94075                    Dimitrios Stephen Petrokokkinos   M  17.0
# 79507   40381  Catherine Marie Blanche "Katie" Gillou (-Fenwick)   F  13.0
# 710       404                        Louis Grenville "Lou" Abell   M  15.0
# 10961    5989                      Gaston Achille Louis Aumoitte   M  15.0
# 10962    5989                      Gaston Achille Louis Aumoitte   M  15.0
#
#         Height  Weight                           Team  NOC        Games  Year  \
# 142882     NaN     NaN  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896
# 51139      NaN     NaN                         France  FRA  1896 Summer  1896
# 182918     NaN     NaN                         Greece  GRE  1896 Summer  1896
# 182919     NaN     NaN                       Greece-2  GRE  1896 Summer  1896
# 187185     NaN     NaN                         Greece  GRE  1896 Summer  1896
# 187186     NaN     NaN                       Greece-1  GRE  1896 Summer  1896
# 79507      NaN     NaN                         France  FRA  1900 Summer  1900
# 710        NaN     NaN               Vesper Boat Club  USA  1900 Summer  1900
# 10961      NaN     NaN                         France  FRA  1900 Summer  1900
# 10962      NaN     NaN                         France  FRA  1900 Summer  1900
#
#         Season    City       Sport                                  Event  \
# 142882  Summer  Athina  Gymnastics  Gymnastics Men's Parallel Bars, Teams
# 51139   Summer  Athina   Athletics             Athletics Men's 800 metres
# 182918  Summer  Athina      Tennis                   Tennis Men's Singles
# 182919  Summer  Athina      Tennis                   Tennis Men's Doubles
# 187185  Summer  Athina      Tennis                   Tennis Men's Singles
# 187186  Summer  Athina      Tennis                   Tennis Men's Doubles
# 79507   Summer   Paris      Tennis                   Tennis Mixed Doubles
# 710     Summer   Paris      Rowing              Rowing Men's Coxed Eights
# 10961   Summer   Paris     Croquet        Croquet Mixed Singles, One Ball
# 10962   Summer   Paris     Croquet                  Croquet Mixed Doubles
#
#          Medal
# 142882  Bronze
# 51139      NaN
# 182918  Bronze
# 182919     NaN
# 187185     NaN
# 187186  Silver
# 79507      NaN
# 710       Gold
# 10961     Gold
# 10962     Gold

# %%
young_athletes.tail(10)
# Out:
#             ID          Name Sex   Age  Height  Weight            Team  NOC  \
# 263878  132043  Xiong Dunhan   F  17.0   181.0    83.0           China  CHN
# 264804  132520   Yang Kun-Pi   M  17.0   186.0   107.0  Chinese Taipei  TPE
# 265767  132980   Tutya Ylmaz   F  17.0   150.0    48.0          Turkey  TUR
# 265768  132980   Tutya Ylmaz   F  17.0   150.0    48.0          Turkey  TUR
# 265769  132980   Tutya Ylmaz   F  17.0   150.0    48.0          Turkey  TUR
# 265770  132980   Tutya Ylmaz   F  17.0   150.0    48.0          Turkey  TUR
# 266535  133336    Yu Jingyao   F  17.0   178.0    63.0           China  CHN
# 269490  134849   Zhu Menghui   F  17.0   177.0    62.0           China  CHN
# 269491  134849   Zhu Menghui   F  17.0   177.0    62.0           China  CHN
# 269492  134849   Zhu Menghui   F  17.0   177.0    62.0           China  CHN
#
#               Games  Year  Season            City       Sport  \
# 263878  2016 Summer  2016  Summer  Rio de Janeiro  Water Polo
# 264804  2016 Summer  2016  Summer  Rio de Janeiro    Shooting
# 265767  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 265768  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 265769  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 265770  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 266535  2016 Summer  2016  Summer  Rio de Janeiro    Swimming
# 269490  2016 Summer  2016  Summer  Rio de Janeiro    Swimming
# 269491  2016 Summer  2016  Summer  Rio de Janeiro    Swimming
# 269492  2016 Summer  2016  Summer  Rio de Janeiro    Swimming
#
#                                                   Event Medal
# 263878                    Water Polo Women's Water Polo   NaN
# 264804                              Shooting Men's Trap   NaN
# 265767         Gymnastics Women's Individual All-Around   NaN
# 265768                Gymnastics Women's Floor Exercise   NaN
# 265769                   Gymnastics Women's Uneven Bars   NaN
# 265770                  Gymnastics Women's Balance Beam   NaN
# 266535         Swimming Women's 200 metres Breaststroke   NaN
# 269490            Swimming Women's 100 metres Freestyle   NaN
# 269491  Swimming Women's 4 x 100 metres Freestyle Relay   NaN
# 269492     Swimming Women's 4 x 100 metres Medley Relay   NaN

# %%
old_athletes = df_athletes[(df_athletes['Age'] >= 60)].sort_values(by = ['Year', 'Age'])

# %%
old_athletes.head(10)
# Out:
#             ID                                               Name Sex   Age  \
# 204709  102794                    Louis Antoine Phocion Rossollin   M  62.0
# 204710  102794                    Louis Antoine Phocion Rossollin   M  62.0
# 204711  102794                    Louis Antoine Phocion Rossollin   M  62.0
# 58985    30189  Louis Jules Henri du Le Vaillant du Douet de G...   M  69.0
# 150753   75648                             Charles William Martin   M  71.0
# 150754   75648                             Charles William Martin   M  71.0
# 150755   75648                             Charles William Martin   M  71.0
# 150756   75648                             Charles William Martin   M  71.0
# 150757   75648                             Charles William Martin   M  71.0
# 150758   75648                             Charles William Martin   M  71.0
#
#         Height  Weight          Team  NOC        Games  Year  Season   City  \
# 204709     NaN     NaN     Ariette-8  FRA  1900 Summer  1900  Summer  Paris
# 204710     NaN     NaN    Ariette-10  FRA  1900 Summer  1900  Summer  Paris
# 204711     NaN     NaN    Ariette-10  FRA  1900 Summer  1900  Summer  Paris
# 58985      NaN     NaN      France-1  FRA  1900 Summer  1900  Summer  Paris
# 150753     NaN     NaN   Crabe II-12  FRA  1900 Summer  1900  Summer  Paris
# 150754     NaN     NaN  Pirouette-31  FRA  1900 Summer  1900  Summer  Paris
# 150755     NaN     NaN    Crabe II-1  FRA  1900 Summer  1900  Summer  Paris
# 150756     NaN     NaN    Crabe II-4  FRA  1900 Summer  1900  Summer  Paris
# 150757     NaN     NaN   Pirouette-5  FRA  1900 Summer  1900  Summer  Paris
# 150758     NaN     NaN   Pirouette-5  FRA  1900 Summer  1900  Summer  Paris
#
#                 Sport                                         Event   Medal
# 204709        Sailing                            Sailing Mixed Open     NaN
# 204710        Sailing                       Sailing Mixed 0.5-1 Ton     NaN
# 204711        Sailing                       Sailing Mixed 0.5-1 Ton     NaN
# 58985   Equestrianism  Equestrianism Mixed Four-In-Hand Competition     NaN
# 150753        Sailing                            Sailing Mixed Open     NaN
# 150754        Sailing                            Sailing Mixed Open     NaN
# 150755        Sailing                       Sailing Mixed 0.5-1 Ton  Silver
# 150756        Sailing                       Sailing Mixed 0.5-1 Ton  Bronze
# 150757        Sailing                        Sailing Mixed 3-10 Ton     NaN
# 150758        Sailing                        Sailing Mixed 3-10 Ton     NaN

# %%
old_athletes.tail(10)
# Out:
#             ID                 Name Sex   Age  Height  Weight           Team  \
# 97374    49287      Hiroshi Hoketsu   M  71.0   168.0    62.0          Japan
# 92741    46990  Suzanne "Sue" Hearn   F  60.0   165.0    68.0      Australia
# 92742    46990  Suzanne "Sue" Hearn   F  60.0   165.0    68.0      Australia
# 240862  120661      Mark James Todd   M  60.0   190.0    78.0    New Zealand
# 240863  120661      Mark James Todd   M  60.0   190.0    78.0    New Zealand
# 259606  129963  John Edwin Whitaker   M  60.0   171.0    70.0  Great Britain
# 259607  129963  John Edwin Whitaker   M  60.0   171.0    70.0  Great Britain
# 90004    45610           Mary Hanna   F  61.0   173.0    63.0      Australia
# 90005    45610           Mary Hanna   F  61.0   173.0    63.0      Australia
# 29912    15436       Julie Brougham   F  62.0   157.0    48.0    New Zealand
#
#         NOC        Games  Year  Season            City          Sport  \
# 97374   JPN  2012 Summer  2012  Summer          London  Equestrianism
# 92741   AUS  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 92742   AUS  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 240862  NZL  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 240863  NZL  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 259606  GBR  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 259607  GBR  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 90004   AUS  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 90005   AUS  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
# 29912   NZL  2016 Summer  2016  Summer  Rio de Janeiro  Equestrianism
#
#                                                   Event Medal
# 97374          Equestrianism Mixed Dressage, Individual   NaN
# 92741          Equestrianism Mixed Dressage, Individual   NaN
# 92742                Equestrianism Mixed Dressage, Team   NaN
# 240862  Equestrianism Mixed Three-Day Event, Individual   NaN
# 240863        Equestrianism Mixed Three-Day Event, Team   NaN
# 259606          Equestrianism Mixed Jumping, Individual   NaN
# 259607                Equestrianism Mixed Jumping, Team   NaN
# 90004          Equestrianism Mixed Dressage, Individual   NaN
# 90005                Equestrianism Mixed Dressage, Team   NaN
# 29912          Equestrianism Mixed Dressage, Individual   NaN

# %%
#prints the records of the youngest and oldest athletes in the dataset

youngest = df_athletes.loc[min_age]
oldest = df_athletes.loc[max_age]

print(youngest)
print(oldest)
# Out:
# ID                                        71691
# Name                         Dimitrios Loundras
# Sex                                           M
# Age                                        10.0
# Height                                      NaN
# Weight                                      NaN
# Team              Ethnikos Gymnastikos Syllogos
# NOC                                         GRE
# Games                               1896 Summer
# Year                                       1896
# Season                                   Summer
# City                                     Athina
# Sport                                Gymnastics
# Event     Gymnastics Men's Parallel Bars, Teams
# Medal                                    Bronze
# Name: 142882, dtype: object
# ID                                             128719
# Name                           John Quincy Adams Ward
# Sex                                                 M
# Age                                              97.0
# Height                                            NaN
# Weight                                            NaN
# Team                                    United States
# NOC                                               USA
# Games                                     1928 Summer
# Year                                             1928
# Season                                         Summer
# City                                        Amsterdam
# Sport                                Art Competitions
# Event     Art Competitions Mixed Sculpturing, Statues
# Medal                                             NaN
# Name: 257054, dtype: object

# %%
import plotly.express as px

# %%
main_table = df_athletes[['Year', 'NOC', 'Medal']]

year = input('Enter the year ')
int_year = int(year)

year_table = main_table[(main_table["Year"] == int_year)].dropna()

group = year_table[['Year', 'NOC', 'Medal']].groupby(['NOC', 'Medal'])
group.count()


#fig = px.bar(medal, x='NOC', y='Year', title = f"{year}'s Olympics Medals by Country")
#fig.show()
# Out:
# Enter the year 2000
#             Year
# NOC Medal
# ALG Bronze     3
#     Gold       1
#     Silver     1
# ARG Bronze     3
#     Silver    17
# ...          ...
# USA Silver    61
# UZB Bronze     2
#     Gold       1
#     Silver     1
# VIE Silver     1
#
# [175 rows x 1 columns]
